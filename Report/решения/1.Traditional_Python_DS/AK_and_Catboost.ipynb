# %% [markdown]
# # Autokeras

# %%
import pandas as pd
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.metrics import AUC, Precision, Recall

import autokeras as ak
# Out:
# 2024-02-09 08:59:13.565882: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-09 08:59:13.611635: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-09 08:59:13.611669: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-09 08:59:13.612835: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-09 08:59:13.620164: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-09 08:59:14.487177: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using TensorFlow backend

# %%
def read_csv_to_dataframe(csv_file_path, delimiter=","):
    """ """
    try:
        # Use pandas to read the CSV file
        dataframe = pd.read_csv(csv_file_path, delimiter=delimiter)
        return dataframe
    except Exception as e:
        print(f"An error occurred while reading the CSV file: {e}")
        return None

# %%
features_file_path = "interview.X.csv"
target_file_path = "interview.y.csv"

features_df = read_csv_to_dataframe(features_file_path)
target_df = read_csv_to_dataframe(target_file_path)

merged_df = features_df.merge(target_df, on="uid", how="left")

del features_df
del target_df

# %%
# Убрать все значения где tag == None
merged_df.dropna(subset=["tag"], inplace=True)
merged_df.shape
# Out:
# (15392, 11)

# %%
# Убираем tag и оставляем только столбец для классификации
merged_df["is_fclick"] = (merged_df["tag"] == "fclick").astype(int)
merged_df.drop("tag", axis=1, inplace=True)

# %%
merged_df.drop_duplicates(inplace=True)
merged_df.reset_index(drop=True, inplace=True)

# %%
merged_df.shape
# Out:
# (12054, 11)

# %%
X = merged_df.drop(columns=["uid", "is_fclick"])
y = merged_df["is_fclick"]
del merged_df

# %%
X["reg_time"] = pd.to_datetime(X["reg_time"])

X["year"] = X["reg_time"].dt.year
X["month"] = X["reg_time"].dt.month
X["day"] = X["reg_time"].dt.day
X["weekday"] = X["reg_time"].dt.weekday

X = X.drop("reg_time", axis=1)

# %%
X['site_id'] = X['site_id'].str.replace('www.', '')
# Out:
# /tmp/ipykernel_113585/4247009660.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   X['site_id'] = X['site_id'].str.replace('www.', '')

# %%
def encode_categories_to_int(dataframe, categoricals):
    """Encodes categorical features contained in `categoricals` list."""

    encoder = {}

    for col in categoricals:
        encoder[col] = {}
        categories = sorted(list(dataframe[col].dropna().astype(str).unique()), key=str)

        for idx, cat in enumerate(categories):
            encoder[col][cat] = idx

        dataframe[col] = dataframe[col].fillna(-1).apply(lambda val: encoder[col].get(str(val), -1))

    return encoder

def decode_int_to_original_category(encoder, dataframe, columns):
    """Decodes integer encoded categorical features."""

    decoded_cols = []

    for col in columns:
        temp_series = []

        for int_val in dataframe[col]:
            temp_series.append(encoder[col].get(int_val, 'Unknown'))

        decoded_col = pd.Series(temp_series, name=col)
        decoded_cols.append(decoded_col)

    decoded_df = pd.concat(decoded_cols, axis=1)
    return decoded_df

# %%
X
# Out:
#        fc_imp_chk  fc_time_chk  utmtr  mm_dma   osName     model  \
# 0               0            7      6     517  Android  SM-N960U
# 1               0            7      6     505  Android  Pixel 4a
# 2               0            7      6     501      iOS    iPhone
# 3               0            7      6     517  Android  SM-G991U
# 4               0            7      6     517  Android  SM-N975U
# ...           ...          ...    ...     ...      ...       ...
# 12049           0            7      5     556      iOS    iPhone
# 12050           0            7      5     556      iOS    iPhone
# 12051           1            6      5       0  Android  SM-G975U
# 12052           3            6      5     567      iOS    iPhone
# 12053           3            6      5     524      iOS    iPhone
#
#            hardware                site_id  year  month  day  weekday
# 0      Mobile Phone         dotesports.com  2021      7   21        2
# 1      Mobile Phone     online.seterra.com  2021      7   21        2
# 2      Mobile Phone           hiphopdx.com  2021      7   21        2
# 3      Mobile Phone       vivaelbirdos.com  2021      7   21        2
# 4      Mobile Phone  landgrantholyland.com  2021      7   21        2
# ...             ...                    ...   ...    ...  ...      ...
# 12049  Mobile Phone         digitalspy.com  2021      8    6        4
# 12050  Mobile Phone         digitalspy.com  2021      8    6        4
# 12051  Mobile Phone         digitalspy.com  2021      8    6        4
# 12052  Mobile Phone        whatculture.com  2021      8    6        4
# 12053  Mobile Phone        whatculture.com  2021      8    6        4
#
# [12054 rows x 12 columns]

# %%
categoricals = ['osName', 'model', 'hardware', 'site_id']
encodings = encode_categories_to_int(X, categoricals)
encodings
# Out:
# {'osName': {'Android': 0,
#   'Linux': 1,
#   'Symbian': 2,
#   'Windows 10': 3,
#   'Windows 7': 4,
#   'iOS': 5},
#  'model': {'1930': 0,
#   '3632A': 1,
#   '5005R': 2,
#   '5007Z': 3,
#   '5032W': 4,
#   '5049S': 5,
#   '5062W': 6,
#   '5062Z': 7,
#   '7': 8,
#   '7.2': 9,
#   '7A': 10,
#   'A3': 11,
#   'A501DL': 12,
#   'A502DL': 13,
#   'A507DL': 14,
#   'A574BL': 15,
#   'A6003': 16,
#   'A6013': 17,
#   'ALP-L09': 18,
#   'Alpha 20': 19,
#   'Armor 9': 20,
#   'BE2012': 21,
#   'BE2015': 22,
#   'BE2025': 23,
#   'BE2028': 24,
#   'C2 Tennen': 25,
#   'CLT-L29': 26,
#   'CP3705A': 27,
#   'Chrome - Linux': 28,
#   'Chrome - Windows': 29,
#   'E6910': 30,
#   'E71': 31,
#   'EA1002': 32,
#   'ELE-L29': 33,
#   'EML-L29': 34,
#   'Edge': 35,
#   'Edge +': 36,
#   'F1': 37,
#   'G011A': 38,
#   'G011C': 39,
#   'G013C': 40,
#   'G61': 41,
#   'G710': 42,
#   'GM1900': 43,
#   'GM1901': 44,
#   'GM1915': 45,
#   'GM1917': 46,
#   'Generic Android Mobile': 47,
#   'Generic Android Tablet': 48,
#   'H8314': 49,
#   'HD1905': 50,
#   'HD1907': 51,
#   'HD1910': 52,
#   'HD1925': 53,
#   'HMA-L29': 54,
#   'HRY-LX1T': 55,
#   'IN2015': 56,
#   'IN2017': 57,
#   'IN2019': 58,
#   'Internet Explorer - Windows': 59,
#   'JNY-LX1': 60,
#   'JSN-L21': 61,
#   'K330': 62,
#   'KB2005': 63,
#   'KB2007': 64,
#   'L322DL': 65,
#   'L355DL': 66,
#   'L423DL': 67,
#   'L455DL': 68,
#   'L555DL': 69,
#   'L722DL': 70,
#   'LE2127': 71,
#   'LM-F100': 72,
#   'LM-G710': 73,
#   'LM-G710VM': 74,
#   'LM-G820': 75,
#   'LM-G850': 76,
#   'LM-G900': 77,
#   'LM-G900TM': 78,
#   'LM-K200': 79,
#   'LM-K300': 80,
#   'LM-K410': 81,
#   'LM-K420': 82,
#   'LM-K500': 83,
#   'LM-K920': 84,
#   'LM-Q620': 85,
#   'LM-Q630': 86,
#   'LM-Q710 (FGN)': 87,
#   'LM-Q720': 88,
#   'LM-Q730': 89,
#   'LM-V350': 90,
#   'LM-V405': 91,
#   'LM-V450': 92,
#   'LM-V600': 93,
#   'LM-X210CMR': 94,
#   'LM-X212(G)': 95,
#   'LM-X220': 96,
#   'LM-X320': 97,
#   'LM-X410 (FG)': 98,
#   'LM-X410.FG': 99,
#   'LM-X420': 100,
#   'LM-X525': 101,
#   'LML211BL': 102,
#   'LML212VL': 103,
#   'LS775': 104,
#   'LS993': 105,
#   'LYA-L29': 106,
#   'M1908C3XG': 107,
#   'M2003J15SC': 108,
#   'M2004J19C': 109,
#   'M2007J20CG': 110,
#   'M2007J3SG': 111,
#   'M2010J19CG': 112,
#   'M430': 113,
#   'MAR-LX1A': 114,
#   'MAR-LX1B': 115,
#   'MP260': 116,
#   'MP450': 117,
#   'MS330': 118,
#   'Mi 8': 119,
#   'Mi 9': 120,
#   'Mi A2': 121,
#   'Mi A2 Lite': 122,
#   'Moto E (2020)': 123,
#   'Moto E4': 124,
#   'Moto E5 Play': 125,
#   'Moto E5 Plus': 126,
#   'Moto E6': 127,
#   'Moto E7 Plus': 128,
#   'Moto G Fast': 129,
#   'Moto G Power': 130,
#   'Moto G Stylus': 131,
#   'Moto G5 Plus': 132,
#   'Moto G6': 133,
#   'Moto G7': 134,
#   'Moto G7 Plus': 135,
#   'Moto G7 Power': 136,
#   'Moto G7 Supra': 137,
#   'Moto G9 Plus': 138,
#   'Moto Z2': 139,
#   'Moto Z3': 140,
#   'Moto Z4': 141,
#   'Moto g stylus 5G': 142,
#   'Note 7': 143,
#   'Note 8 Pro': 144,
#   'Note 9 Pro': 145,
#   'One 5G ace': 146,
#   'One Fusion Plus': 147,
#   'One Hyper': 148,
#   'POT-LX1': 149,
#   'POT-LX1AF': 150,
#   'Phone 2': 151,
#   'Pixel': 152,
#   'Pixel 3': 153,
#   'Pixel 3a': 154,
#   'Pixel 3a XL': 155,
#   'Pixel 4': 156,
#   'Pixel 4 XL': 157,
#   'Pixel 4a': 158,
#   'Pixel 5': 159,
#   'Pixel XL': 160,
#   'Pocophone F1': 161,
#   'Q710AL': 162,
#   'REVVL 2': 163,
#   'RMX1971': 164,
#   'Redmi 8': 165,
#   'Redmi Note 8': 166,
#   'Revvlry': 167,
#   'Revvlry+': 168,
#   'S52': 169,
#   'S62 Pro': 170,
#   'SM-A015A': 171,
#   'SM-A015T1': 172,
#   'SM-A015V': 173,
#   'SM-A025AZ': 174,
#   'SM-A025U': 175,
#   'SM-A102U': 176,
#   'SM-A105FN': 177,
#   'SM-A107M': 178,
#   'SM-A115A': 179,
#   'SM-A115AZ': 180,
#   'SM-A115U': 181,
#   'SM-A125M': 182,
#   'SM-A125U': 183,
#   'SM-A205U': 184,
#   'SM-A205U1': 185,
#   'SM-A215U': 186,
#   'SM-A217F': 187,
#   'SM-A315G': 188,
#   'SM-A326U': 189,
#   'SM-A405FN': 190,
#   'SM-A426U': 191,
#   'SM-A426U1': 192,
#   'SM-A505F': 193,
#   'SM-A505FN': 194,
#   'SM-A505U': 195,
#   'SM-A505U1': 196,
#   'SM-A515F': 197,
#   'SM-A515F/DSN': 198,
#   'SM-A515U': 199,
#   'SM-A515U1': 200,
#   'SM-A516U': 201,
#   'SM-A516V': 202,
#   'SM-A526U': 203,
#   'SM-A600FN': 204,
#   'SM-A600P': 205,
#   'SM-A605FN': 206,
#   'SM-A715F': 207,
#   'SM-A716U': 208,
#   'SM-A716U1': 209,
#   'SM-A716V': 210,
#   'SM-A920F': 211,
#   'SM-F700U1/DS': 212,
#   'SM-F707U1': 213,
#   'SM-F900U': 214,
#   'SM-F916U': 215,
#   'SM-G550T1': 216,
#   'SM-G770U1': 217,
#   'SM-G781U': 218,
#   'SM-G781U1/DS': 219,
#   'SM-G781V': 220,
#   'SM-G890A': 221,
#   'SM-G892A': 222,
#   'SM-G900V': 223,
#   'SM-G920V': 224,
#   'SM-G930A': 225,
#   'SM-G930P': 226,
#   'SM-G930T': 227,
#   'SM-G930V': 228,
#   'SM-G935F': 229,
#   'SM-G935V': 230,
#   'SM-G950U': 231,
#   'SM-G950U1': 232,
#   'SM-G955U': 233,
#   'SM-G960F': 234,
#   'SM-G960U': 235,
#   'SM-G960U1': 236,
#   'SM-G965F': 237,
#   'SM-G965U': 238,
#   'SM-G965U1': 239,
#   'SM-G970F': 240,
#   'SM-G970U': 241,
#   'SM-G970U1': 242,
#   'SM-G973F': 243,
#   'SM-G973U': 244,
#   'SM-G973U1': 245,
#   'SM-G975F': 246,
#   'SM-G975U': 247,
#   'SM-G975U1': 248,
#   'SM-G977U': 249,
#   'SM-G980F': 250,
#   'SM-G981U': 251,
#   'SM-G981U1': 252,
#   'SM-G981V': 253,
#   'SM-G985F': 254,
#   'SM-G986U': 255,
#   'SM-G988B': 256,
#   'SM-G988U': 257,
#   'SM-G991U': 258,
#   'SM-G991U1': 259,
#   'SM-G996U': 260,
#   'SM-G996U1': 261,
#   'SM-G998U': 262,
#   'SM-G998U1': 263,
#   'SM-J260T1': 264,
#   'SM-J327A': 265,
#   'SM-J327T': 266,
#   'SM-J327V': 267,
#   'SM-J337V': 268,
#   'SM-J337VPP': 269,
#   'SM-J415FN': 270,
#   'SM-J600FN': 271,
#   'SM-J727A': 272,
#   'SM-J727AZ': 273,
#   'SM-J727T1': 274,
#   'SM-J727V': 275,
#   'SM-J737A': 276,
#   'SM-J737P': 277,
#   'SM-J737T': 278,
#   'SM-J737T1': 279,
#   'SM-J737V': 280,
#   'SM-M205FN/DS': 281,
#   'SM-M215F': 282,
#   'SM-N950U': 283,
#   'SM-N950U1': 284,
#   'SM-N960F': 285,
#   'SM-N960U': 286,
#   'SM-N960U1': 287,
#   'SM-N970U': 288,
#   'SM-N970U1': 289,
#   'SM-N975U': 290,
#   'SM-N975U1': 291,
#   'SM-N976U': 292,
#   'SM-N976V': 293,
#   'SM-N981U': 294,
#   'SM-N981U1': 295,
#   'SM-N986U': 296,
#   'SM-N986U1': 297,
#   'SM-S102DL': 298,
#   'SM-S111DL': 299,
#   'SM-S115DL': 300,
#   'SM-S127DL': 301,
#   'SM-S205DL': 302,
#   'SM-S215DL': 303,
#   'SM-S260DL': 304,
#   'SM-S327VL': 305,
#   'SM-S337TL': 306,
#   'SM-S367VL': 307,
#   'SM-S506DL': 308,
#   'SM-S515DL': 309,
#   'SM-S727VL': 310,
#   'SM-S767VL': 311,
#   'SNE-LX1': 312,
#   'STK-LX1': 313,
#   'T770B': 314,
#   'T790W': 315,
#   'T790Z': 316,
#   'TA-1005': 317,
#   'TP450': 318,
#   'U307AS': 319,
#   'U520AS': 320,
#   'U693CL': 321,
#   'VOG-L29': 322,
#   'VS500': 323,
#   'VS988': 324,
#   'VS996': 325,
#   'XQ-AT51': 326,
#   'XT1254': 327,
#   'XT1635-01': 328,
#   'XT1650': 329,
#   'XT1921-2': 330,
#   'XT1955DL': 331,
#   'XT2005DL': 332,
#   'XT2041DL': 333,
#   'XT2052DL': 334,
#   'XT2075-1': 335,
#   'XT2115DL': 336,
#   'YAL-L21': 337,
#   'Z3153V': 338,
#   'cp3705AS': 339,
#   'iPad': 340,
#   'iPhone': 341,
#   'iPhone 11': 342,
#   'iPhone 11 Pro': 343,
#   'iPhone 11 Pro Max': 344,
#   'iPhone 12': 345,
#   'iPhone 12 Mini': 346,
#   'iPhone 12 Pro': 347,
#   'iPhone 12 Pro Max': 348,
#   'iPhone 6S': 349,
#   'iPhone 6S Plus': 350,
#   'iPhone 7': 351,
#   'iPhone 7 Plus': 352,
#   'iPhone 8': 353,
#   'iPhone 8 Plus': 354,
#   'iPhone SE': 355,
#   'iPhone SE (2nd generation)': 356,
#   'iPhone X': 357,
#   'iPhone XR': 358,
#   'iPhone XS': 359,
#   'iPhone XS Max': 360,
#   'iPod Touch': 361,
#   'moto g play (2021)': 362,
#   'moto g power (2021)': 363,
#   'moto g stylus (2021)': 364},
#  'hardware': {'Desktop': 0,
#   'Media Player': 1,
#   'Mobile Phone': 2,
#   'Mobile+Phone': 3,
#   'Tablet': 4},
#  'site_id': {'100krecipes.com': 0,
#   '1057thehawk.com': 1,
#   '10tv.com': 2,
#   '11alive.com': 3,
#   '13abc.com': 4,
#   '14ymedio.com': 5,
#   '247sports.com': 6,
#   '40aprons.com': 7,
#   '41nbc.com': 8,
#   '6abc.com': 9,
#   'abc12.com': 10,
#   'abc13.com': 11,
#   'abc15.com': 12,
#   'abc27.com': 13,
#   'abc3340.com': 14,
#   'abc7.com': 15,
#   'abc7news.com': 16,
#   'abc7ny.com': 17,
#   'abcactionnews.com': 18,
#   'abcnews.go.com': 19,
#   'aboutspiritual.com': 20,
#   'accuweather.com': 21,
#   'acmepackingcompany.com': 22,
#   'acouplecooks.com': 23,
#   'actuallygoodteamnames.com': 24,
#   'adishofdailylife.com': 25,
#   'adventure.howstuffworks.com': 26,
#   'afarmgirlskitchen.com': 27,
#   'aforkstale.com': 28,
#   'aggieskitchen.com': 29,
#   'ahoramismo.com': 30,
#   'air-fried.com': 31,
#   'airalamo.com': 32,
#   'akc.org': 33,
#   'al.com': 34,
#   'allabouttrh.com': 35,
#   'allrecipes.com': 36,
#   'allthatsinteresting.com': 37,
#   'allturtles.com': 38,
#   'amandascookin.com': 39,
#   'americansongwriter.com': 40,
#   'amotherfarfromhome.com': 41,
#   'amp.charlotteobserver.com': 42,
#   'amp.denver.cbslocal.com': 43,
#   'amp.kansascity.com': 44,
#   'amp.losangeles.cbslocal.com': 45,
#   'amp.mercurynews.com': 46,
#   'amp.miamiherald.com': 47,
#   'amp.star-telegram.com': 48,
#   'amp.vox.com': 49,
#   'amusingfoodie.com': 50,
#   'anaffairfromtheheart.com': 51,
#   'anandabazar.com': 52,
#   'anglija.today': 53,
#   'animalcrossingworld.com': 54,
#   'animated-teeth.com': 55,
#   'anoffgridlife.com': 56,
#   'antiques.lovetoknow.com': 57,
#   'aol.com': 58,
#   'apnews.com': 59,
#   'appleinsider.com': 60,
#   'arayofsunlight.com': 61,
#   'areinventedmom.com': 62,
#   'aroundmyfamilytable.com': 63,
#   'arrowheadpride.com': 64,
#   'artfrommytable.com': 65,
#   'articlesnewz.com': 66,
#   'artsychicksrule.com': 67,
#   'aseaofblue.com': 68,
#   'askchefdennis.com': 69,
#   'askthedentist.com': 70,
#   'assurancewireless.myfirstly.com': 71,
#   'astrology-zodiac-signs.com': 72,
#   'astrology.com': 73,
#   'astrosofa.com': 74,
#   'athleticsnation.com': 75,
#   'atlanta.eater.com': 76,
#   'atlantablackstar.com': 77,
#   'atlantamagazine.com': 78,
#   'attackontitan.fandom.com': 79,
#   'atthehive.com': 80,
#   'auburnpub.com': 81,
#   'audacy.com': 82,
#   'augustacrime.com': 83,
#   'autoevolution.com': 84,
#   'autos.yahoo.com': 85,
#   'avaz.ba': 86,
#   'avclub.com': 87,
#   'averiecooks.com': 88,
#   'awealthofcommonsense.com': 89,
#   'awesomemitten.com': 90,
#   'azlyrics.com': 91,
#   'baby.lovetoknow.com': 92,
#   'babylonbee.com': 93,
#   'backroadramblers.com': 94,
#   'backtomysouthernroots.com': 95,
#   'backyardscape.com': 96,
#   'baconismagic.ca': 97,
#   'badlefthook.com': 98,
#   'bakeat350.net': 99,
#   'bakerbynature.com': 100,
#   'bakingamoment.com': 101,
#   'bakingkneads.com': 102,
#   'bakingmischief.com': 103,
#   'baldursgate.fandom.com': 104,
#   'baltimore.cbslocal.com': 105,
#   'baltimorebeatdown.com': 106,
#   'barcablaugranes.com': 107,
#   'barefeetinthekitchen.com': 108,
#   'barrescueupdates.com': 109,
#   'baseball-reference.com': 110,
#   'baseballamerica.com': 111,
#   'batesfamilyblog.com': 112,
#   'bavarianfootballworks.com': 113,
#   'bayart.org': 114,
#   'bddatabase.net': 115,
#   'beautifuldawndesigns.net': 116,
#   'behindthename.com': 117,
#   'behindthesteelcurtain.com': 118,
#   'belleofthekitchen.com': 119,
#   'bellsbomb.baseball.cbssports.com': 120,
#   'beloitdailynews.com': 121,
#   'benzinga.com': 122,
#   'berrymaple.com': 123,
#   'best-of-oahu.com': 124,
#   'bestclassicbands.com': 125,
#   'bestlifeonline.com': 126,
#   'bestofarkansassports.com': 127,
#   'bible.knowing-jesus.com': 128,
#   'biblereasons.com': 129,
#   'bigblueview.com': 130,
#   'bikeforums.net': 131,
#   'billyparisi.com': 132,
#   'bitzngiggles.com': 133,
#   'blackenterprise.com': 134,
#   'blavity.com': 135,
#   'blazepress.com': 136,
#   'bleedingcool.com': 137,
#   'blessedbeyondcrazy.com': 138,
#   'blesserhouse.com': 139,
#   'blog.cheapism.com': 140,
#   'blog.theanimalrescuesite.greatergood.com': 141,
#   'bloggingtheboys.com': 142,
#   'blogmickey.com': 143,
#   'blogs.fangraphs.com': 144,
#   'bloodyelbow.com': 145,
#   'blueshirtbanter.com': 146,
#   'bnd.com': 147,
#   'boltsfromtheblue.com': 148,
#   'bookseriesinorder.com': 149,
#   'bookslikethisone.com': 150,
#   'boredpanda.com': 151,
#   'boston.cbslocal.com': 152,
#   'boston.com': 153,
#   'bostonherald.com': 154,
#   'bowlofdelicious.com': 155,
#   'boxing247.com': 156,
#   'breakingweather.net': 157,
#   'brewcrewball.com': 158,
#   'broadstreethockey.com': 159,
#   'brooklynfarmgirl.com': 160,
#   'browneyedbaker.com': 161,
#   'brownsnation.com': 162,
#   'budgetbytes.com': 163,
#   'buffalonews.com': 164,
#   'buffalorumblings.com': 165,
#   'buildyourbite.com': 166,
#   'bulletsforever.com': 167,
#   'burntorangenation.com': 168,
#   'businessinsider.com': 169,
#   'bustle.com': 170,
#   'busytourist.com': 171,
#   'butterwithasideofbread.com': 172,
#   'butteryourbiscuit.com': 173,
#   'buzzaboutbees.net': 174,
#   'buzzfeed.com': 175,
#   'buzzfeednews.com': 176,
#   'bybrittanygoldwyn.com': 177,
#   'bysophialee.com': 178,
#   'cafedelites.com': 179,
#   'cafepharma.com': 180,
#   'cagesideseats.com': 181,
#   'calculatorsoup.com': 182,
#   'callmepmc.com': 183,
#   'camdenchat.com': 184,
#   'canalstreetchronicles.com': 185,
#   'candles.lovetoknow.com': 186,
#   'canescountry.com': 187,
#   'cardchronicle.com': 188,
#   'careeraddict.com': 189,
#   'carlsbadcravings.com': 190,
#   'cartilagefreecaptain.sbnation.com': 191,
#   'cartreatments.com': 192,
#   'cbr.com': 193,
#   'cbs4indy.com': 194,
#   'cbsnews.com': 195,
#   'cbssports.com': 196,
#   'cenduparam.com': 197,
#   'centralillinoisproud.com': 198,
#   'channel3000.com': 199,
#   'charlotteobserver.com': 200,
#   'charlotteonthecheap.com': 201,
#   'cheatdaydesign.com': 202,
#   'cheatsheet.com': 203,
#   'cheeseheadtv.com': 204,
#   'chef-in-training.com': 205,
#   'chelseasmessyapron.com': 206,
#   'chelsweets.com': 207,
#   'chevroletforum.com': 208,
#   'chicago.cbslocal.com': 209,
#   'chicago.suntimes.com': 210,
#   'chicagotribune.com': 211,
#   'chicpursuit.com': 212,
#   'childinsider.com': 213,
#   'chilipeppermadness.com': 214,
#   'chinatimes.com': 215,
#   'chrissymarieblog.com': 216,
#   'christiancamppro.com': 217,
#   'chunkbase.com': 218,
#   'clara.es': 219,
#   'clarkscondensed.com': 220,
#   'cleantechnica.com': 221,
#   'cleveland.com': 222,
#   'cleveland19.com': 223,
#   'clevelandtraveler.com': 224,
#   'click2houston.com': 225,
#   'clickondetroit.com': 226,
#   'clickorlando.com': 227,
#   'closerweekly.com': 228,
#   'clubhouse.swingu.com': 229,
#   'clublexus.com': 230,
#   'clutchpoints.com': 231,
#   'cnbc.com': 232,
#   'cnc3.co.tt': 233,
#   'coleandmarmalade.com': 234,
#   'comicbook.com': 235,
#   'comicbookmovie.com': 236,
#   'comicsheatingup.net': 237,
#   'community.babycenter.com': 238,
#   'complex.com': 239,
#   'conversationstartersworld.com': 240,
#   'cookieandkate.com': 241,
#   'cookingclassy.com': 242,
#   'cookinglight.com': 243,
#   'cookinglsl.com': 244,
#   'cookingwithcarlee.com': 245,
#   'cookingwithmammac.com': 246,
#   'cookitonce.com': 247,
#   'corvetteforum.com': 248,
#   'cosmopolitan.com': 249,
#   'countrydiaries.com': 250,
#   'countryliving.com': 251,
#   'countrymusicnation.com': 252,
#   'countrynow.com': 253,
#   'countryrebel.com': 254,
#   'coupletraveltheworld.com': 255,
#   'coveringthecorner.com': 256,
#   'cowboyswire.usatoday.com': 257,
#   'cozypeachkitchen.com': 258,
#   'craftbeering.com': 259,
#   'craftycookingmama.com': 260,
#   'cravingcalifornia.com': 261,
#   'crayonsandcravings.com': 262,
#   'crazydaysandnights.net': 263,
#   'crazyforcrust.com': 264,
#   'createandfind.com': 265,
#   'createcraftlove.com': 266,
#   'creators.com': 267,
#   'crfashionbook.com': 268,
#   'crispyfoodidea.com': 269,
#   'criticalrole.fandom.com': 270,
#   'crockpotsandflipflops.com': 271,
#   'crowdmedia.pl': 272,
#   'cruisehive.com': 273,
#   'crystalandcomp.com': 274,
#   'culinaryhill.com': 275,
#   'culturaencadena.com': 276,
#   'cupcakediariesblog.com': 277,
#   'curatedinterior.com': 278,
#   'curiouscuisiniere.com': 279,
#   'currently.att.yahoo.com': 280,
#   'cutefetti.com': 281,
#   'cuteness.com': 282,
#   'cyclingweekly.com': 283,
#   'dailycal.org': 284,
#   'dailydot.com': 285,
#   'dailymotion.com': 286,
#   'dailyvoice.com': 287,
#   'daisyfarmcrafts.com': 288,
#   'damndelicious.net': 289,
#   'dangerous-business.com': 290,
#   'danslelakehouse.com': 291,
#   'dapperconfidential.com': 292,
#   'daquan.tv': 293,
#   'darciesdish.com': 294,
#   'dashofsanity.com': 295,
#   'dawsonnews.com': 296,
#   'deadline.com': 297,
#   'deadspin.com': 298,
#   'deckshop.pro': 299,
#   'deepfriedhoney.com': 300,
#   'defeatingdivorce.com': 301,
#   'defensacentral.com': 302,
#   'defused.com': 303,
#   'delish.com': 304,
#   'delishknowledge.com': 305,
#   'denofgeek.com': 306,
#   'denverpost.com': 307,
#   'designingidea.com': 308,
#   'dessertnowdinnerlater.com': 309,
#   'detoxinista.com': 310,
#   'detroitbadboys.com': 311,
#   'detroitnews.com': 312,
#   'detroitsportsnation.com': 313,
#   'dexter.fandom.com': 314,
#   'dfw.cbslocal.com': 315,
#   'diariolibre.com': 316,
#   'diaryofasocalmama.com': 317,
#   'diebytheblade.com': 318,
#   'diethood.com': 319,
#   'digitalcameraworld.com': 320,
#   'digitalspy.com': 321,
#   'dinner-mom.com': 322,
#   'dinneratthezoo.com': 323,
#   'dinnerthendessert.com': 324,
#   'dirt.com': 325,
#   'dirtysouthsoccer.com': 326,
#   'discovertheburgh.com': 327,
#   'discoverytime.com': 328,
#   'disneytouristblog.com': 329,
#   'disneytrippers.com': 330,
#   'distractify.com': 331,
#   'dmv-practice-test.com': 332,
#   'dmv-written-test.com': 333,
#   'doesitgobad.com': 334,
#   'dogfoodsmart.com': 335,
#   'doggysaurus.com': 336,
#   'dolphinnation.com': 337,
#   'dongknows.com': 338,
#   'donotdisturbgardening.com': 339,
#   'dotesports.com': 340,
#   'downshiftology.com': 341,
#   'dragonball.fandom.com': 342,
#   'dreamsinheels.com': 343,
#   'drf.com': 344,
#   'drinkteatravel.com': 345,
#   'drivinvibin.com': 346,
#   'dualshockers.com': 347,
#   'dukebasketballreport.com': 348,
#   'dziennikwschodni.pl': 349,
#   'earnsmartonlineclass.com': 350,
#   'earth911.com': 351,
#   'easybabylife.com': 352,
#   'easybudgetrecipes.com': 353,
#   'easychickenrecipes.com': 354,
#   'easyfamilyrecipes.com': 355,
#   'easyweeknightrecipes.com': 356,
#   'eater.com': 357,
#   'eatthis.com': 358,
#   'eatwithclarity.com': 359,
#   'edition.cuteness.com': 360,
#   'edition.pethelpful.com': 361,
#   'edition.si.com': 362,
#   'edition.stacker.com': 363,
#   'edition.thrillist.com': 364,
#   'el-ahly.com': 365,
#   'elderscrolls.fandom.com': 366,
#   'elespectador.com': 367,
#   'elitedaily.com': 368,
#   'elle.com': 369,
#   'elle.com.au': 370,
#   'elledecor.com': 371,
#   'elnuevoherald.com': 372,
#   'elsoldepuebla.com.mx': 373,
#   'emailquizzes.com': 374,
#   'embed.video.yahoo.com': 375,
#   'empiresportsmedia.com': 376,
#   'empoweredsinglemoms.com': 377,
#   'enjoymomlife.com': 378,
#   'eonline.com': 379,
#   'epicstream.com': 380,
#   'erienewsnow.com': 381,
#   'es.dmv-written-test.com': 382,
#   'es.gizmodo.com': 383,
#   'es.lovetoknow.com': 384,
#   'espanol.yahoo.com': 385,
#   'espn.com': 386,
#   'esquire.com': 387,
#   'etonline.com': 388,
#   'eventhubs.com': 389,
#   'everydayoldhouse.com': 390,
#   'ew.com': 391,
#   'examples.yourdictionary.com': 392,
#   'explorenowornever.com': 393,
#   'expres.sk': 394,
#   'express.co.uk': 395,
#   'extremetech.com': 396,
#   'f150forum.com': 397,
#   'f150online.com': 398,
#   'fakeginger.com': 399,
#   'familydestinationsguide.com': 400,
#   'familyfreshmeals.com': 401,
#   'familystylefood.com': 402,
#   'fancypantshomes.com': 403,
#   'fantabulosity.com': 404,
#   'farmfoodfamily.com': 405,
#   'farmingmybackyard.com': 406,
#   'fastcompany.com': 407,
#   'favfamilyrecipes.com': 408,
#   'fearthesword.com': 409,
#   'federalnewsnetwork.com': 410,
#   'feedmephoebe.com': 411,
#   'feelslikehomeblog.com': 412,
#   'ffxiv.consolegameswiki.com': 413,
#   'fieldandstream.com': 414,
#   'fieldgulls.com': 415,
#   'finance.yahoo.com': 416,
#   'findyourmomtribe.com': 417,
#   'firstforwomen.com': 418,
#   'fishlab.com': 419,
#   'fitwirr.com': 420,
#   'fivespotgreenliving.com': 421,
#   'flickeringmyth.com': 422,
#   'flightaware.com': 423,
#   'florida-backroads-travel.com': 424,
#   'floridarambler.com': 425,
#   'flouronmyface.com': 426,
#   'flypeachpie.com': 427,
#   'fnbr.co': 428,
#   'fodmapeveryday.com': 429,
#   'folhavitoria.com.br': 430,
#   'foodabovegold.com': 431,
#   'foodfaithfitness.com': 432,
#   'foodiecrush.com': 433,
#   'foodlove.com': 434,
#   'foodnetwork.com': 435,
#   'foolproofliving.com': 436,
#   'footwearnews.com': 437,
#   'forbes.com': 438,
#   'forsythnews.com': 439,
#   'fortnitetracker.com': 440,
#   'fortune.com': 441,
#   'forums.realgm.com': 442,
#   'forums.rivals.com': 443,
#   'fox17.com': 444,
#   'fox17online.com': 445,
#   'fox19.com': 446,
#   'fox29.com': 447,
#   'fox2now.com': 448,
#   'fox35orlando.com': 449,
#   'fox47news.com': 450,
#   'fox4kc.com': 451,
#   'fox59.com': 452,
#   'fox6now.com': 453,
#   'fox8live.com': 454,
#   'foxandbriar.com': 455,
#   'foxbusiness.com': 456,
#   'foxcarolina.com': 457,
#   'foxsanantonio.com': 458,
#   'freep.com': 459,
#   'frommers.com': 460,
#   'fstoppers.com': 461,
#   'futureofworking.com': 462,
#   'gamefaqs.gamespot.com': 463,
#   'gamepress.gg': 464,
#   'gamepur.com': 465,
#   'gamerant.com': 466,
#   'gamerguides.com': 467,
#   'gamerjournalist.com': 468,
#   'games.playwpt.com': 469,
#   'gamespot.com': 470,
#   'gamesradar.com': 471,
#   'gardenbetty.com': 472,
#   'gardenforindoor.com': 473,
#   'gardening.org': 474,
#   'gardeningchannel.com': 475,
#   'gardeningknowhow.com': 476,
#   'gardentabs.com': 477,
#   'garmentsofsplendor.com': 478,
#   'gazetatema.net': 479,
#   'geektyrant.com': 480,
#   'genius.com': 481,
#   'gentside.co.uk': 482,
#   'getawaycouple.com': 483,
#   'getbusygardening.com': 484,
#   'giantfreakinrobot.com': 485,
#   'gimmedelicious.com': 486,
#   'gimmesomeoven.com': 487,
#   'girlinthegarage.net': 488,
#   'girlscangrill.com': 489,
#   'girlschannel.net': 490,
#   'gizmodo.com': 491,
#   'globalmunchkins.com': 492,
#   'glutenfreebaking.com': 493,
#   'god.dailydot.com': 494,
#   'goldenstateofmind.com': 495,
#   'goodfoodstories.com': 496,
#   'goodhousekeeping.com': 497,
#   'goodnewsnetwork.org': 498,
#   'gopetfriendly.com': 499,
#   'gopherballs.baseball.cbssports.com': 500,
#   'gosunoob.com': 501,
#   'gpsmycity.com': 502,
#   'graceandgoodeats.com': 503,
#   'graceandlightness.com': 504,
#   'grammar.yourdictionary.com': 505,
#   'grandbaby-cakes.com': 506,
#   'granniesjokes.com': 507,
#   'greedygourmet.com': 508,
#   'greenandketo.com': 509,
#   'greenwichtime.com': 510,
#   'gretastravels.com': 511,
#   'groundstobrew.com': 512,
#   'grunge.com': 513,
#   'guitarplayer.com': 514,
#   'h2ouse.org': 515,
#   'haakmaarraak.nl': 516,
#   'hammerandrails.com': 517,
#   'happinessishomemade.net': 518,
#   'happyhappyvegan.com': 519,
#   'happymomhacks.com': 520,
#   'harlemworldmagazine.com': 521,
#   'harpersbazaar.com': 522,
#   'harvesttotable.com': 523,
#   'hawaiitravelwithkids.com': 524,
#   'hbcugameday.com': 525,
#   'hdforums.com': 526,
#   'healthline.com': 527,
#   'healthyandnaturalworld.com': 528,
#   'healthylittlepeach.com': 529,
#   'healthyseasonalrecipes.com': 530,
#   'hearthookhome.com': 531,
#   'heartlandcollegesports.com': 532,
#   'heartmybackpack.com': 533,
#   'heavy.com': 534,
#   'hellogiggles.com': 535,
#   'helloglow.co': 536,
#   'hellomagazine.com': 537,
#   'hellskitchen.fandom.com': 538,
#   'heraldonline.com': 539,
#   'hero.fandom.com': 540,
#   'herviewfromhome.com': 541,
#   'herway.net': 542,
#   'heywandererblog.com': 543,
#   'heywise.com': 544,
#   'hfboards.mandatory.com': 545,
#   'highschoolot.com': 546,
#   'hip-hopvibe.com': 547,
#   'hiphopdx.com': 548,
#   'hltv.org': 549,
#   'hockeywilderness.com': 550,
#   'holajalapeno.com': 551,
#   'hollyhabeck.com': 552,
#   'hollywood.com': 553,
#   'home.howstuffworks.com': 554,
#   'homeguides.sfgate.com': 555,
#   'homehacks.co': 556,
#   'homemadefoodjunkie.com': 557,
#   'homestead-acres.com': 558,
#   'homestratosphere.com': 559,
#   'hometalk.com': 560,
#   'honeyandbirch.com': 561,
#   'hoopshype.com': 562,
#   'horoscope.com': 563,
#   'hostessatheart.com': 564,
#   'hot97.com': 565,
#   'hotcars.com': 566,
#   'housebeautiful.com': 567,
#   'houseofnasheats.com': 568,
#   'houseofyumm.com': 569,
#   'housewifehowtos.com': 570,
#   'houstonpress.com': 571,
#   'howsweeteats.com': 572,
#   'howtofixit.net': 573,
#   'howtothisandthat.com': 574,
#   'hu.motorsport.com': 575,
#   'hunker.com': 576,
#   'hurrythefoodup.com': 577,
#   'iamhomesteader.com': 578,
#   'icecreamconvos.com': 579,
#   'icy-veins.com': 580,
#   'ifamilykc.com': 581,
#   'igotmyrefund.com': 582,
#   'iheartnaptime.net': 583,
#   'ihorror.com': 584,
#   'imamother.com': 585,
#   'imore.com': 586,
#   'improvesailing.com': 587,
#   'inc.com': 588,
#   'independent.co.uk': 589,
#   'indianajo.com': 590,
#   'indiewire.com': 591,
#   'indoorhomegarden.com': 592,
#   'infotakers.com': 593,
#   'inquirer.com': 594,
#   'insanelygoodrecipes.com': 595,
#   'insider.com': 596,
#   'insidethemagic.net': 597,
#   'insightstate.com': 598,
#   'inspirationalmomma.com': 599,
#   'inspiredbride.net': 600,
#   'inspiredbycharm.com': 601,
#   'instrupix.com': 602,
#   'instyle.com': 603,
#   'interestingengineering.com': 604,
#   'international-players-baseball-league.baseball.cbssports.com': 605,
#   'intouchweekly.com': 606,
#   'inverse.com': 607,
#   'iphonelife.com': 608,
#   'italianpolishmomma.com': 609,
#   'itrwrestling.com': 610,
#   'itsavegworldafterall.com': 611,
#   'itstillruns.com': 612,
#   'jacketscannon.com': 613,
#   'jaguarswire.usatoday.com': 614,
#   'jalopnik.com': 615,
#   'japantimes.co.jp': 616,
#   'japersrink.com': 617,
#   'jenmerckling.com': 618,
#   'jennakateathome.com': 619,
#   'jenniferbanz.com': 620,
#   'jenniraincloud.com': 621,
#   'jerseygirlcooks.com': 622,
#   'jezebel.com': 623,
#   'joaobidu.com.br': 624,
#   'journalnow.com': 625,
#   'journalstar.com': 626,
#   'journeytosahm.com': 627,
#   'joyfoodsunshine.com': 628,
#   'jsonline.com': 629,
#   'jugantor.com': 630,
#   'julieblanner.com': 631,
#   'justonecookbook.com': 632,
#   'justsimplymom.com': 633,
#   'jz-eats.com': 634,
#   'k9ofmine.com': 635,
#   'kait8.com': 636,
#   'kansas.com': 637,
#   'katc.com': 638,
#   'katv.com': 639,
#   'kcrg.com': 640,
#   'kennythepirate.com': 641,
#   'ketodietrule.com': 642,
#   'ketodietyum.com': 643,
#   'kfgo.com': 644,
#   'kfor.com': 645,
#   'kidactivities.net': 646,
#   'kidadl.com': 647,
#   'kidsactivitiesblog.com': 648,
#   'kidscraftroom.com': 649,
#   'kleinworthco.com': 650,
#   'kltv.com': 651,
#   'knbr.com': 652,
#   'knockoffdecor.com': 653,
#   'knoe.com': 654,
#   'kold.com': 655,
#   'kolotv.com': 656,
#   'kompas.com': 657,
#   'kotaku.com': 658,
#   'kpopmap.com': 659,
#   'kristineskitchenblog.com': 660,
#   'kristv.com': 661,
#   'ksat.com': 662,
#   'ksdk.com': 663,
#   'ksla.com': 664,
#   'ksnt.com': 665,
#   'ktvb.com': 666,
#   'kudoskitchenbyrenee.com': 667,
#   'kvue.com': 668,
#   'kwch.com': 669,
#   'kxii.com': 670,
#   'ky3.com': 671,
#   'kyleecooks.com': 672,
#   'ladyleeshome.com': 673,
#   'lajollamom.com': 674,
#   'lakersnation.com': 675,
#   'lalalisette.com': 676,
#   'landgrantholyland.com': 677,
#   'las2orillas.co': 678,
#   'lasvegasthenandnow.com': 679,
#   'latimes.com': 680,
#   'latimescrosswordanswers.com': 681,
#   'laughingsquid.com': 682,
#   'laurengreutman.com': 683,
#   'laurenslatest.com': 684,
#   'leaf.tv': 685,
#   'lebanon24.com': 686,
#   'lecremedelacrumb.com': 687,
#   'legacy.com': 688,
#   'lehighvalleylive.com': 689,
#   'lemonblossoms.com': 690,
#   'lemonslavenderandlaundry.com': 691,
#   'lemontreedwelling.com': 692,
#   'letsdishrecipes.com': 693,
#   'letsrun.com': 694,
#   'letstravelfamily.com': 695,
#   'levelwinner.com': 696,
#   'levvvel.com': 697,
#   'lex18.com': 698,
#   'libertyballers.com': 699,
#   'lifehacker.com': 700,
#   'lifehacks.io': 701,
#   'lifejacketadvisor.com': 702,
#   'lifelive.eu': 703,
#   'lifemadesweeter.com': 704,
#   'littlebroken.com': 705,
#   'littlespicejar.com': 706,
#   'littleyellowwheelbarrow.com': 707,
#   'live5news.com': 708,
#   'livecorestrong.com': 709,
#   'liveeatlearn.com': 710,
#   'livelytable.com': 711,
#   'livenewsworld.com': 712,
#   'livescience.com': 713,
#   'livestrong.com': 714,
#   'livewellbakeoften.com': 715,
#   'livewellzone.com': 716,
#   'livforcake.com': 717,
#   'livinlifewithlori.com': 718,
#   'local10.com': 719,
#   'logiastarata.gr': 720,
#   'lonestarball.com': 721,
#   'longbournfarm.com': 722,
#   'longhornswire.usatoday.com': 723,
#   'longisland.news12.com': 724,
#   'lonzowire.usatoday.com': 725,
#   'loopsandlovecrochet.com': 726,
#   'lordbyronskitchen.com': 727,
#   'losangeles.cbslocal.com': 728,
#   'loudersound.com': 729,
#   'louisvillefamilyfun.net': 730,
#   'lovebscott.com': 731,
#   'lovecatalogue.com': 732,
#   'lovedevani.com': 733,
#   'lovefoodies.com': 734,
#   'lovefromtheoven.com': 735,
#   'loveliliya.com': 736,
#   'loveourlittles.com': 737,
#   'loveremodeled.com': 738,
#   'lovewhatmatters.com': 739,
#   'lovingitvegan.com': 740,
#   'luvze.com': 741,
#   'luxurycolumnist.com': 742,
#   'm.activebeat.com': 743,
#   'm.akhbarelyom.com': 744,
#   'm.bernabeudigital.com': 745,
#   'm.bulbapedia.bulbagarden.net': 746,
#   'm.creaders.net': 747,
#   'm.dailyleader.com': 748,
#   'm.elsalvador.com': 749,
#   'm.eluniversal.com.co': 750,
#   'm.extra.globo.com': 751,
#   'm.fame10.com': 752,
#   'm.fangol.pl': 753,
#   'm.huffingtonpost.es': 754,
#   'm.lobservateur.com': 755,
#   'm.oxfordeagle.com': 756,
#   'm.panews.com': 757,
#   'm.rediff.com': 758,
#   'maduradas.com': 759,
#   'magnoliastatelive.com': 760,
#   'maizenbrew.com': 761,
#   'makeitfrommetal.com': 762,
#   'mandatory.com': 763,
#   'marisamoore.com': 764,
#   'marketrealist.com': 765,
#   'marketwatch.com': 766,
#   'marriage.com': 767,
#   'mashed.com': 768,
#   'masonfit.com': 769,
#   'mathwarehouse.com': 770,
#   'mavsmoneyball.com': 771,
#   'mbworld.org': 772,
#   'meaww.com': 773,
#   'media.11alive.com': 774,
#   'medicaldaily.com': 775,
#   'medicalnewstoday.com': 776,
#   'meganstarr.com': 777,
#   'melskitchencafe.com': 778,
#   'menshealth.com': 779,
#   'mentalfloss.com': 780,
#   'merakilane.com': 781,
#   'mercurynews.com': 782,
#   'metro.pr': 783,
#   'metropcs.mobi': 784,
#   'metropcs.mobileposse.com': 785,
#   'miakouppa.com': 786,
#   'miamidiario.com': 787,
#   'miamiherald.com': 788,
#   'microwavemealprep.com': 789,
#   'midlifehealthyliving.com': 790,
#   'milb.com': 791,
#   'milehighreport.com': 792,
#   'mindfulnessandjustice.org': 793,
#   'minecraft.fandom.com': 794,
#   'minimalistbaker.com': 795,
#   'ministryofcurry.com': 796,
#   'miniwebtool.com': 797,
#   'minnesota.cbslocal.com': 798,
#   'miraculousladybug.fandom.com': 799,
#   'mirror.co.uk': 800,
#   'missinthekitchen.com': 801,
#   'mmafighting.com': 802,
#   'mmamania.com': 803,
#   'mobile.reuters.com': 804,
#   'modernhoney.com': 805,
#   'momadvice.com': 806,
#   'mominformed.com': 807,
#   'momlikeyoumeanit.com': 808,
#   'momlovesbest.com': 809,
#   'mommalew.com': 810,
#   'mommycantaffordthat.com': 811,
#   'momsandmunchkins.ca': 812,
#   'money.yahoo.com': 813,
#   'moneyinc.com': 814,
#   'moneysavingbasics.com': 815,
#   'moneywise.com': 816,
#   'morethanmeatandpotatoes.com': 817,
#   'morningchores.com': 818,
#   'motosan.es': 819,
#   'movieweb.com': 820,
#   'movimentocountry.com': 821,
#   'mrfood.com': 822,
#   'msnbc.com': 823,
#   'mundohispanico.com': 824,
#   'muranochickenfarm.com': 825,
#   'murphysmultiverse.com': 826,
#   'musicmayhemmagazine.com': 827,
#   'my.xfinity.com': 828,
#   'my100yearoldhome.com': 829,
#   'mybakingaddiction.com': 830,
#   'mycakeschool.com': 831,
#   'mycbs4.com': 832,
#   'myfox8.com': 833,
#   'mygolfspy.com': 834,
#   'myhappyhusky.com': 835,
#   'mymommystyle.com': 836,
#   'mymontanakitchen.com': 837,
#   'myorganizedchaos.net': 838,
#   'mypcoskitchen.com': 839,
#   'mypoppet.com.au': 840,
#   'mypositiveoutlooks.com': 841,
#   'myrecipes.com': 842,
#   'myweddingsongs.com': 843,
#   'naruto.fandom.com': 844,
#   'nasdaq.com': 845,
#   'nashvillefunforfamilies.com': 846,
#   'natchezdemocrat.com': 847,
#   'nationaldaycalendar.com': 848,
#   'nationalinterest.org': 849,
#   'naturalhair-products.com': 850,
#   'nbaanalysis.net': 851,
#   'nbc12.com': 852,
#   'nbc29.com': 853,
#   'nbcsports.com': 854,
#   'nbcsportsedge.com': 855,
#   'ncronline.org': 856,
#   'netsdaily.com': 857,
#   'newjersey.news12.com': 858,
#   'news.com.au': 859,
#   'news.rediff.com': 860,
#   'news.yahoo.com': 861,
#   'news4jax.com': 862,
#   'news5cleveland.com': 863,
#   'newschannel20.com': 864,
#   'newschannel5.com': 865,
#   'newsely.com': 866,
#   'newsweek.com': 867,
#   'newsweek.ro': 868,
#   'newyork.cbslocal.com': 869,
#   'nextluxury.com': 870,
#   'nfltraderumors.co': 871,
#   'nickiswift.com': 872,
#   'nj.com': 873,
#   'nme.com': 874,
#   'nogluten.com': 875,
#   'nola.eater.com': 876,
#   'northernnester.com': 877,
#   'noshtastic.com': 878,
#   'numerologynation.com': 879,
#   'nunesmagician.com': 880,
#   'nutmegnanny.com': 881,
#   'nvdaily.com': 882,
#   'nwitimes.com': 883,
#   'nxslink.myfox8.com': 884,
#   'ny.curbed.com': 885,
#   'nydailynews.com': 886,
#   'nymag.com': 887,
#   'nypost.com': 888,
#   'nytimes.com': 889,
#   'nz.news.yahoo.com': 890,
#   'nzherald.co.nz': 891,
#   'oards.com': 892,
#   'obits.nj.com': 893,
#   'obits.nola.com': 894,
#   'obits.theadvocate.com': 895,
#   'observer-reporter.com': 896,
#   'obxtoday.com': 897,
#   'oddlycutepets.com': 898,
#   'odia.ig.com.br': 899,
#   'ohmrstucker.com': 900,
#   'ohsweetbasil.com': 901,
#   'okmagazine.com': 902,
#   'oldsportscards.com': 903,
#   'oldworldgardenfarms.com': 904,
#   'oliviascuisine.com': 905,
#   'omaha.com': 906,
#   'onceuponachef.com': 907,
#   'onedishkitchen.com': 908,
#   'onefrugalgirl.com': 909,
#   'onegoodthingbyjillee.com': 910,
#   'onekindesign.com': 911,
#   'onewholesomelife.com': 912,
#   'online.seterra.com': 913,
#   'onlinejigsawpuzzles.net': 914,
#   'onthisday.com': 915,
#   'orlandodatenightguide.com': 916,
#   'orwhateveryoudo.com': 917,
#   'ourcatholicprayers.com': 918,
#   'ourdailybears.com': 919,
#   'ourhomemadeeasy.com': 920,
#   'ourlads.com': 921,
#   'ourmindfullife.com': 922,
#   'outdoorhappens.com': 923,
#   'outdoorlife.com': 924,
#   'outgrilling.com': 925,
#   'outkick.com': 926,
#   'outsports.com': 927,
#   'overthemonster.com': 928,
#   'pagesix.com': 929,
#   'pajiba.com': 930,
#   'paleorunningmomma.com': 931,
#   'pandagossips.com': 932,
#   'pantherswire.usatoday.com': 933,
#   'parade.com': 934,
#   'parents.com': 935,
#   'parksavers.com': 936,
#   'pastrychefonline.com': 937,
#   'patspulpit.com': 938,
#   'payetteforward.com': 939,
#   'pcgamer.com': 940,
#   'pcgamesn.com': 941,
#   'pdfwonder.com': 942,
#   'peachtreehoops.com': 943,
#   'pennlive.com': 944,
#   'pensburgh.com': 945,
#   'people.com': 946,
#   'people.howstuffworks.com': 947,
#   'pep.ph': 948,
#   'persnicketyplates.com': 949,
#   'petapixel.com': 950,
#   'petfoodreviewer.com': 951,
#   'philadelphia.cbslocal.com': 952,
#   'philliesnation.com': 953,
#   'picrew.me': 954,
#   'pinchandswirl.com': 955,
#   'pinstripealley.com': 956,
#   'pittsburgh.cbslocal.com': 957,
#   'planetf1.com': 958,
#   'planetware.com': 959,
#   'plantbasedandbroke.com': 960,
#   'platedcravings.com': 961,
#   'plattertalk.com': 962,
#   'playbuzz.com': 963,
#   'playpartyplan.com': 964,
#   'pmnewsnigeria.com': 965,
#   'pointedkitchen.com': 966,
#   'polygon.com': 967,
#   'popcrush.com': 968,
#   'postingandtoasting.com': 969,
#   'poundingtherock.com': 970,
#   'powerliftingtechnique.com': 971,
#   'practicalwanderlust.com': 972,
#   'prepbaseballreport.com': 973,
#   'preppykitchen.com': 974,
#   'prevention.com': 975,
#   'prideofdetroit.com': 976,
#   'princesspinkygirl.com': 977,
#   'pro-football-reference.com': 978,
#   'profesorjitaruionel.com': 979,
#   'professional-counselling.com': 980,
#   'profootballnetwork.com': 981,
#   'profusioncurry.com': 982,
#   'projecthotmess.com': 983,
#   'prosportsdaily.com': 984,
#   'prothomalo.com': 985,
#   'psychreel.com': 986,
#   'pumpkinnspice.com': 987,
#   'quizdaily.com': 988,
#   'rachelcooks.com': 989,
#   'radaronline.com': 990,
#   'radiofacts.com': 991,
#   'raialyoum.com': 992,
#   'rainydaymum.co.uk': 993,
#   'raisingteenstoday.com': 994,
#   'rankedboost.com': 995,
#   'rap-up.com': 996,
#   'rarehistoricalphotos.com': 997,
#   'rasamalaysia.com': 998,
#   'ratemyprofessors.com': 999,
#   ...}}

# %%
scaler = MinMaxScaler()
X[["fc_imp_chk", "fc_time_chk", "utmtr", "mm_dma"]] = scaler.fit_transform(
    X[["fc_imp_chk", "fc_time_chk", "utmtr", "mm_dma"]]
)

# %%
from imblearn.over_sampling import ADASYN

# Предположим, у вас есть матрица признаков X и вектор целевых значений y
# X - это ваши признаки (например, числовые или категориальные)
# y - это целевая переменная (например, бинарная классификация: 0 или 1)

# Создаем экземпляр ADASYN
adasyn = ADASYN(random_state=42)

# Применяем ADASYN к данным
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Теперь X_resampled и y_resampled содержат сбалансированные данные
# Вы можете использовать их для обучения модели машинного обучения
X_resampled.shape, y_resampled.shape
# Out:
# ((16082, 12), (16082,))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.3, random_state=42, shuffle=True
)

# %%
X
# Out:
#        fc_imp_chk  fc_time_chk     utmtr    mm_dma  osName  model  hardware  \
# 0            0.00          1.0  0.857143  0.586833       0    286         2
# 1            0.00          1.0  0.857143  0.573212       0    158         2
# 2            0.00          1.0  0.857143  0.568672       5    341         2
# 3            0.00          1.0  0.857143  0.586833       0    258         2
# 4            0.00          1.0  0.857143  0.586833       0    290         2
# ...           ...          ...       ...       ...     ...    ...       ...
# 12049        0.00          1.0  0.714286  0.631101       5    341         2
# 12050        0.00          1.0  0.714286  0.631101       5    341         2
# 12051        0.25          0.0  0.714286  0.000000       0    247         2
# 12052        0.75          0.0  0.714286  0.643587       5    341         2
# 12053        0.75          0.0  0.714286  0.594779       5    341         2
#
#        site_id  year  month  day  weekday
# 0          340  2021      7   21        2
# 1          913  2021      7   21        2
# 2          548  2021      7   21        2
# 3         1340  2021      7   21        2
# 4          677  2021      7   21        2
# ...        ...   ...    ...  ...      ...
# 12049      321  2021      8    6        4
# 12050      321  2021      8    6        4
# 12051      321  2021      8    6        4
# 12052     1372  2021      8    6        4
# 12053     1372  2021      8    6        4
#
# [12054 rows x 12 columns]

# %%
clf = ak.StructuredDataClassifier(
    column_names=[
        "fc_imp_chk",
        "fc_time_chk",
        "utmtr",
        "mm_dma",
        "osName",
        "hardware",
        "model",
        "site_id",
        "year",
        "month",
        "day",
        "weekday",
    ],
    column_types={
        "fc_imp_chk":"numerical",
        "fc_time_chk":"numerical",
        "utmtr":"numerical",
        "mm_dma":"numerical",
        "osName":"numerical",
        "hardware": "numerical",
        "model":"numerical",
        "site_id": "numerical",
        "year":"numerical",
        "month":"numerical",
        "day":"numerical",
        "weekday":"numerical"
    },
    max_trials=50,
    overwrite=False,
    tuner="greedy",
)
# Out:
# Reloading Tuner from ./structured_data_classifier/tuner0.json

# %%
clf.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# 2024-02-09 08:59:18.918161: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-09 08:59:18.967635: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-09 08:59:18.971307: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-09 08:59:18.975018: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-09 08:59:18.978167: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-09 08:59:18.981103: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-09 08:59:19.128462: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-09 08:59:19.129845: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-09 08:59:19.130989: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-09 08:59:19.132025: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# 2024-02-09 08:59:20.811974: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Epoch 1/100
# 2024-02-09 08:59:24.647225: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f6bab009b30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-02-09 08:59:24.647262: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-02-09 08:59:24.653450: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-02-09 08:59:24.673181: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1707469164.769392  113853 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 352/352 [==============================] - 4s 4ms/step - loss: 0.6664 - accuracy: 0.5887 - val_loss: 0.6480 - val_accuracy: 0.6035
# Epoch 2/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6478 - accuracy: 0.6186 - val_loss: 0.6411 - val_accuracy: 0.6288
# Epoch 3/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6429 - accuracy: 0.6313 - val_loss: 0.6374 - val_accuracy: 0.6404
# Epoch 4/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6382 - accuracy: 0.6422 - val_loss: 0.6341 - val_accuracy: 0.6528
# Epoch 5/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6364 - accuracy: 0.6438 - val_loss: 0.6319 - val_accuracy: 0.6560
# Epoch 6/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6337 - accuracy: 0.6513 - val_loss: 0.6297 - val_accuracy: 0.6593
# Epoch 7/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6319 - accuracy: 0.6511 - val_loss: 0.6278 - val_accuracy: 0.6624
# Epoch 8/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6278 - accuracy: 0.6583 - val_loss: 0.6259 - val_accuracy: 0.6674
# Epoch 9/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6274 - accuracy: 0.6624 - val_loss: 0.6246 - val_accuracy: 0.6690
# Epoch 10/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6262 - accuracy: 0.6666 - val_loss: 0.6230 - val_accuracy: 0.6732
# Epoch 11/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6244 - accuracy: 0.6653 - val_loss: 0.6218 - val_accuracy: 0.6734
# Epoch 12/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6237 - accuracy: 0.6663 - val_loss: 0.6207 - val_accuracy: 0.6752
# Epoch 13/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6232 - accuracy: 0.6655 - val_loss: 0.6195 - val_accuracy: 0.6759
# Epoch 14/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6208 - accuracy: 0.6692 - val_loss: 0.6184 - val_accuracy: 0.6767
# Epoch 15/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6204 - accuracy: 0.6707 - val_loss: 0.6175 - val_accuracy: 0.6775
# Epoch 16/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6179 - accuracy: 0.6695 - val_loss: 0.6166 - val_accuracy: 0.6781
# Epoch 17/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6182 - accuracy: 0.6726 - val_loss: 0.6158 - val_accuracy: 0.6796
# Epoch 18/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6178 - accuracy: 0.6720 - val_loss: 0.6150 - val_accuracy: 0.6796
# Epoch 19/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6164 - accuracy: 0.6719 - val_loss: 0.6142 - val_accuracy: 0.6802
# Epoch 20/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.6147 - accuracy: 0.6733 - val_loss: 0.6135 - val_accuracy: 0.6802
# Epoch 21/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6141 - accuracy: 0.6749 - val_loss: 0.6127 - val_accuracy: 0.6802
# Epoch 22/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6134 - accuracy: 0.6758 - val_loss: 0.6121 - val_accuracy: 0.6812
# Epoch 23/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6145 - accuracy: 0.6738 - val_loss: 0.6113 - val_accuracy: 0.6808
# Epoch 24/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6122 - accuracy: 0.6753 - val_loss: 0.6108 - val_accuracy: 0.6827
# Epoch 25/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6128 - accuracy: 0.6752 - val_loss: 0.6104 - val_accuracy: 0.6837
# Epoch 26/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6113 - accuracy: 0.6731 - val_loss: 0.6100 - val_accuracy: 0.6827
# Epoch 27/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6117 - accuracy: 0.6746 - val_loss: 0.6095 - val_accuracy: 0.6835
# Epoch 28/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6104 - accuracy: 0.6779 - val_loss: 0.6091 - val_accuracy: 0.6831
# Epoch 29/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6102 - accuracy: 0.6769 - val_loss: 0.6087 - val_accuracy: 0.6831
# Epoch 30/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6099 - accuracy: 0.6778 - val_loss: 0.6081 - val_accuracy: 0.6839
# Epoch 31/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6089 - accuracy: 0.6781 - val_loss: 0.6077 - val_accuracy: 0.6837
# Epoch 32/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6086 - accuracy: 0.6784 - val_loss: 0.6072 - val_accuracy: 0.6841
# Epoch 33/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6072 - accuracy: 0.6791 - val_loss: 0.6067 - val_accuracy: 0.6856
# Epoch 34/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6077 - accuracy: 0.6810 - val_loss: 0.6064 - val_accuracy: 0.6860
# Epoch 35/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.6080 - accuracy: 0.6774 - val_loss: 0.6063 - val_accuracy: 0.6866
# Epoch 36/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6051 - accuracy: 0.6782 - val_loss: 0.6059 - val_accuracy: 0.6862
# Epoch 37/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6068 - accuracy: 0.6785 - val_loss: 0.6055 - val_accuracy: 0.6852
# Epoch 38/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6047 - accuracy: 0.6795 - val_loss: 0.6052 - val_accuracy: 0.6862
# Epoch 39/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6044 - accuracy: 0.6815 - val_loss: 0.6050 - val_accuracy: 0.6866
# Epoch 40/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6051 - accuracy: 0.6813 - val_loss: 0.6047 - val_accuracy: 0.6868
# Epoch 41/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6049 - accuracy: 0.6798 - val_loss: 0.6043 - val_accuracy: 0.6873
# Epoch 42/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6039 - accuracy: 0.6806 - val_loss: 0.6040 - val_accuracy: 0.6866
# Epoch 43/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6050 - accuracy: 0.6811 - val_loss: 0.6038 - val_accuracy: 0.6860
# Epoch 44/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6046 - accuracy: 0.6813 - val_loss: 0.6036 - val_accuracy: 0.6866
# Epoch 45/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6041 - accuracy: 0.6806 - val_loss: 0.6034 - val_accuracy: 0.6873
# Epoch 46/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6026 - accuracy: 0.6789 - val_loss: 0.6029 - val_accuracy: 0.6860
# Epoch 47/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6026 - accuracy: 0.6829 - val_loss: 0.6027 - val_accuracy: 0.6864
# Epoch 48/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6028 - accuracy: 0.6797 - val_loss: 0.6024 - val_accuracy: 0.6856
# Epoch 49/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6012 - accuracy: 0.6831 - val_loss: 0.6022 - val_accuracy: 0.6860
# Epoch 50/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6024 - accuracy: 0.6790 - val_loss: 0.6021 - val_accuracy: 0.6873
# Epoch 51/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6032 - accuracy: 0.6812 - val_loss: 0.6020 - val_accuracy: 0.6877
# Epoch 52/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6011 - accuracy: 0.6817 - val_loss: 0.6015 - val_accuracy: 0.6864
# Epoch 53/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6000 - accuracy: 0.6822 - val_loss: 0.6014 - val_accuracy: 0.6868
# Epoch 54/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5997 - accuracy: 0.6816 - val_loss: 0.6011 - val_accuracy: 0.6875
# Epoch 55/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6021 - accuracy: 0.6798 - val_loss: 0.6007 - val_accuracy: 0.6870
# Epoch 56/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5990 - accuracy: 0.6832 - val_loss: 0.6005 - val_accuracy: 0.6875
# Epoch 57/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.6012 - accuracy: 0.6834 - val_loss: 0.6004 - val_accuracy: 0.6864
# Epoch 58/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5985 - accuracy: 0.6814 - val_loss: 0.6001 - val_accuracy: 0.6875
# Epoch 59/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5975 - accuracy: 0.6848 - val_loss: 0.6000 - val_accuracy: 0.6873
# Epoch 60/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5976 - accuracy: 0.6850 - val_loss: 0.5997 - val_accuracy: 0.6875
# Epoch 61/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5973 - accuracy: 0.6836 - val_loss: 0.5995 - val_accuracy: 0.6870
# Epoch 62/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5975 - accuracy: 0.6841 - val_loss: 0.5993 - val_accuracy: 0.6875
# Epoch 63/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5981 - accuracy: 0.6848 - val_loss: 0.5990 - val_accuracy: 0.6875
# Epoch 64/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5970 - accuracy: 0.6822 - val_loss: 0.5989 - val_accuracy: 0.6879
# Epoch 65/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5971 - accuracy: 0.6860 - val_loss: 0.5989 - val_accuracy: 0.6877
# Epoch 66/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5965 - accuracy: 0.6839 - val_loss: 0.5987 - val_accuracy: 0.6887
# Epoch 67/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5960 - accuracy: 0.6849 - val_loss: 0.5984 - val_accuracy: 0.6891
# Epoch 68/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5962 - accuracy: 0.6806 - val_loss: 0.5982 - val_accuracy: 0.6877
# Epoch 69/100
# 352/352 [==============================] - 2s 4ms/step - loss: 0.5948 - accuracy: 0.6825 - val_loss: 0.5980 - val_accuracy: 0.6885
# Epoch 70/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5941 - accuracy: 0.6865 - val_loss: 0.5977 - val_accuracy: 0.6877
# Epoch 71/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5949 - accuracy: 0.6865 - val_loss: 0.5975 - val_accuracy: 0.6885
# Epoch 72/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5937 - accuracy: 0.6856 - val_loss: 0.5973 - val_accuracy: 0.6887
# Epoch 73/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5941 - accuracy: 0.6854 - val_loss: 0.5972 - val_accuracy: 0.6885
# Epoch 74/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5940 - accuracy: 0.6859 - val_loss: 0.5972 - val_accuracy: 0.6883
# Epoch 75/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5937 - accuracy: 0.6837 - val_loss: 0.5968 - val_accuracy: 0.6885
# Epoch 76/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5938 - accuracy: 0.6857 - val_loss: 0.5969 - val_accuracy: 0.6877
# Epoch 77/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5943 - accuracy: 0.6846 - val_loss: 0.5966 - val_accuracy: 0.6889
# Epoch 78/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5928 - accuracy: 0.6878 - val_loss: 0.5967 - val_accuracy: 0.6889
# Epoch 79/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5913 - accuracy: 0.6875 - val_loss: 0.5964 - val_accuracy: 0.6885
# Epoch 80/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5917 - accuracy: 0.6856 - val_loss: 0.5965 - val_accuracy: 0.6887
# Epoch 81/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5915 - accuracy: 0.6890 - val_loss: 0.5962 - val_accuracy: 0.6887
# Epoch 82/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5922 - accuracy: 0.6860 - val_loss: 0.5961 - val_accuracy: 0.6897
# Epoch 83/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5925 - accuracy: 0.6867 - val_loss: 0.5956 - val_accuracy: 0.6879
# Epoch 84/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5910 - accuracy: 0.6870 - val_loss: 0.5957 - val_accuracy: 0.6887
# Epoch 85/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5901 - accuracy: 0.6908 - val_loss: 0.5956 - val_accuracy: 0.6891
# Epoch 86/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5921 - accuracy: 0.6851 - val_loss: 0.5956 - val_accuracy: 0.6887
# Epoch 87/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5909 - accuracy: 0.6877 - val_loss: 0.5953 - val_accuracy: 0.6895
# Epoch 88/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5912 - accuracy: 0.6853 - val_loss: 0.5954 - val_accuracy: 0.6897
# Epoch 89/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5906 - accuracy: 0.6870 - val_loss: 0.5953 - val_accuracy: 0.6893
# Epoch 90/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5907 - accuracy: 0.6892 - val_loss: 0.5949 - val_accuracy: 0.6904
# Epoch 91/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5902 - accuracy: 0.6854 - val_loss: 0.5951 - val_accuracy: 0.6893
# Epoch 92/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5905 - accuracy: 0.6876 - val_loss: 0.5949 - val_accuracy: 0.6879
# Epoch 93/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5893 - accuracy: 0.6856 - val_loss: 0.5946 - val_accuracy: 0.6881
# Epoch 94/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5873 - accuracy: 0.6929 - val_loss: 0.5944 - val_accuracy: 0.6899
# Epoch 95/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5876 - accuracy: 0.6884 - val_loss: 0.5944 - val_accuracy: 0.6893
# Epoch 96/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5886 - accuracy: 0.6889 - val_loss: 0.5942 - val_accuracy: 0.6904
# Epoch 97/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5892 - accuracy: 0.6862 - val_loss: 0.5938 - val_accuracy: 0.6902
# Epoch 98/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5877 - accuracy: 0.6872 - val_loss: 0.5939 - val_accuracy: 0.6918
# Epoch 99/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5899 - accuracy: 0.6819 - val_loss: 0.5940 - val_accuracy: 0.6908
# Epoch 100/100
# 352/352 [==============================] - 1s 4ms/step - loss: 0.5872 - accuracy: 0.6882 - val_loss: 0.5937 - val_accuracy: 0.6941
# INFO:tensorflow:Assets written to: ./structured_data_classifier/best_model/assets
# INFO:tensorflow:Assets written to: ./structured_data_classifier/best_model/assets

# %%
predictions = clf.predict(X_test)
report = classification_report(y_test, predictions)
print(report)
# Out:
# 151/151 [==============================] - 0s 2ms/step
# 151/151 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.73      0.64      0.68      2456
#            1       0.67      0.75      0.71      2369
#
#     accuracy                           0.69      4825
#    macro avg       0.70      0.70      0.69      4825
# weighted avg       0.70      0.69      0.69      4825

# %%
model = clf.export_model()
model.save("model_autokeras", save_format="tf")
# Out:
# INFO:tensorflow:Assets written to: model_autokeras/assets
# INFO:tensorflow:Assets written to: model_autokeras/assets

# %% [markdown]
# ## Catboost

# %%
import pandas as pd
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Initialize CatBoostClassifier
model = CatBoostClassifier(
    iterations=50000, learning_rate=0.1, depth=6, loss_function="Logloss", verbose=1000
)

# Fit model
model.fit(X_train, y_train)

# Make predictions
predictions = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")

# Save model
model.save_model("catboost_classifier.model")
# Out:
# 0:	learn: 0.6770006	total: 4.8ms	remaining: 4m
# 1000:	learn: 0.3206980	total: 4.06s	remaining: 3m 18s
# 2000:	learn: 0.2806091	total: 8.25s	remaining: 3m 18s
# 3000:	learn: 0.2583342	total: 12.3s	remaining: 3m 12s
# 4000:	learn: 0.2440839	total: 16.4s	remaining: 3m 8s
# 5000:	learn: 0.2337920	total: 20.5s	remaining: 3m 4s
# 6000:	learn: 0.2263383	total: 24.6s	remaining: 3m
# 7000:	learn: 0.2207898	total: 28.8s	remaining: 2m 56s
# 8000:	learn: 0.2163618	total: 32.9s	remaining: 2m 52s
# 9000:	learn: 0.2128685	total: 37.1s	remaining: 2m 49s
# 10000:	learn: 0.2099961	total: 41.1s	remaining: 2m 44s
# 11000:	learn: 0.2075583	total: 45.1s	remaining: 2m 40s
# 12000:	learn: 0.2054234	total: 49.2s	remaining: 2m 35s
# 13000:	learn: 0.2037671	total: 53.1s	remaining: 2m 31s
# 14000:	learn: 0.2023012	total: 57s	remaining: 2m 26s
# 15000:	learn: 0.2010717	total: 1m	remaining: 2m 22s
# 16000:	learn: 0.2000215	total: 1m 4s	remaining: 2m 17s
# 17000:	learn: 0.1991814	total: 1m 8s	remaining: 2m 13s
# 18000:	learn: 0.1984288	total: 1m 12s	remaining: 2m 8s
# 19000:	learn: 0.1976537	total: 1m 16s	remaining: 2m 4s
# 20000:	learn: 0.1970295	total: 1m 19s	remaining: 1m 59s
# 21000:	learn: 0.1964925	total: 1m 23s	remaining: 1m 55s
# 22000:	learn: 0.1959502	total: 1m 27s	remaining: 1m 50s
# 23000:	learn: 0.1955673	total: 1m 30s	remaining: 1m 46s
# 24000:	learn: 0.1951652	total: 1m 34s	remaining: 1m 41s
# 25000:	learn: 0.1948705	total: 1m 37s	remaining: 1m 37s
# 26000:	learn: 0.1945685	total: 1m 41s	remaining: 1m 33s
# 27000:	learn: 0.1942852	total: 1m 44s	remaining: 1m 28s
# 28000:	learn: 0.1940317	total: 1m 47s	remaining: 1m 24s
# 29000:	learn: 0.1937391	total: 1m 51s	remaining: 1m 20s
# 30000:	learn: 0.1934971	total: 1m 54s	remaining: 1m 16s
# 31000:	learn: 0.1933489	total: 1m 58s	remaining: 1m 12s
# 32000:	learn: 0.1931915	total: 2m 1s	remaining: 1m 8s
# 33000:	learn: 0.1930077	total: 2m 4s	remaining: 1m 4s
# 34000:	learn: 0.1928273	total: 2m 8s	remaining: 1m
# 35000:	learn: 0.1926741	total: 2m 11s	remaining: 56.4s
# 36000:	learn: 0.1925394	total: 2m 15s	remaining: 52.5s
# 37000:	learn: 0.1923912	total: 2m 18s	remaining: 48.6s
# 38000:	learn: 0.1922540	total: 2m 21s	remaining: 44.7s
# 39000:	learn: 0.1921388	total: 2m 24s	remaining: 40.9s
# 40000:	learn: 0.1920147	total: 2m 28s	remaining: 37.1s
# 41000:	learn: 0.1918903	total: 2m 31s	remaining: 33.3s
# 42000:	learn: 0.1917710	total: 2m 34s	remaining: 29.5s
# 43000:	learn: 0.1916572	total: 2m 38s	remaining: 25.8s
# 44000:	learn: 0.1915498	total: 2m 41s	remaining: 22s
# 45000:	learn: 0.1914516	total: 2m 44s	remaining: 18.3s
# 46000:	learn: 0.1913597	total: 2m 48s	remaining: 14.6s
# 47000:	learn: 0.1912613	total: 2m 51s	remaining: 10.9s
# 48000:	learn: 0.1911246	total: 2m 54s	remaining: 7.27s
# 49000:	learn: 0.1910312	total: 2m 57s	remaining: 3.63s
# 49999:	learn: 0.1909300	total: 3m 1s	remaining: 0us
# Accuracy: 0.6692227979274611
